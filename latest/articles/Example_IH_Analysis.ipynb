# %% [markdown]
# > **📦 Optional dependencies**
# >
# > This article uses features from the pdstools `adm` extra. Install with your favorite package manager, e.g. `pip install "pdstools[adm]"`.

# %%
# These lines are only for rendering in the docs, and are hidden through Jupyter tags
# Do not run if you're running the notebook seperately
# Hidden from doc by virtue of cell tags - in VSCode right-click on the bar to the left of this cell, edit cell tags, see metadata

import plotly.io as pio
import plotly as plotly

# plotly.offline.init_notebook_mode()
# pio.renderers.default = "vscode"

pio.renderers.default = "notebook_connected"

# %% [markdown]
# # Example IH (Interaction History) Analysis
#
# Interaction History (IH) is a rich source of data at the level of individual interactions from Pega DSM applications like CDH. It contains the time of the interaction, the channel, the actions/treatments, the customer ID and is used to track different types of outcomes (decisions, sends, opens, clicks, etc). It does **not** contain details of individual customers - only their ID's.
#
# Interaction History is typically used to analyze customer behavior and optimize decision strategies. The following sections provide various example analyses that can be performed on IH data, including distribution analysis, response analysis, success rates, model performance, propensity distribution, and response time analysis.
#
# Like most of PDSTools, it uses [plotly](https://plotly.com/python/) for visualization and [polars](https://docs.pola.rs/) (dataframe) but the purpose of this Notebook is more to serve example analyses than re-usable code, although of course we already provide some generic, re-usable functions. All of the analyses should be able to be replicated easily in other analytical BI environments - except perhaps the analysis of model performance / AUC.
#
# This notebook uses mock data generated by PDS Tools. Replace it with your own actual IH data and modify the analyses as appropriate.

# %%
from pdstools import IH
import polars as pl
# ih = IH.from_ds_export(
#     "../../data/Data-pxStrategyResult_pxInteractionHistory_20210101T010000_GMT.zip"
# )
ih = IH.from_mock_data(n=1e5, seed=42)

# %% [markdown]
# Preview of the raw IH data

# %%
ih.data.head().collect()
# Out:
# shape: (5, 13)
# ┌────────────┬─────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Interactio ┆ Channel ┆ Issue     ┆ Group     ┆ … ┆ Direction ┆ Outcome   ┆ BasePrope ┆ Propensit │
# │ nID        ┆ ---     ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ nsity     ┆ y         │
# │ ---        ┆ str     ┆ str       ┆ str       ┆   ┆ str       ┆ str       ┆ ---       ┆ ---       │
# │ str        ┆         ┆           ┆           ┆   ┆           ┆           ┆ f64       ┆ f64       │
# ╞════════════╪═════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1000000000 ┆ Email   ┆ Risk      ┆ Savings   ┆ … ┆ Outbound  ┆ Pending   ┆ 0.004013  ┆ 0.003964  │
# │ 1000000001 ┆ Web     ┆ Risk      ┆ Lending   ┆ … ┆ Inbound   ┆ Impressio ┆ 0.008533  ┆ 0.008444  │
# │            ┆         ┆           ┆           ┆   ┆           ┆ n         ┆           ┆           │
# │ 1000000002 ┆ Web     ┆ Risk      ┆ Investmen ┆ … ┆ Inbound   ┆ Impressio ┆ 0.022318  ┆ 0.022583  │
# │            ┆         ┆           ┆ ts        ┆   ┆           ┆ n         ┆           ┆           │
# │ 1000000003 ┆ Web     ┆ Service   ┆ Insurance ┆ … ┆ Inbound   ┆ Impressio ┆ 0.019342  ┆ 0.01805   │
# │            ┆         ┆           ┆           ┆   ┆           ┆ n         ┆           ┆           │
# │ 1000000004 ┆ Email   ┆ Acquisiti ┆ Mortgages ┆ … ┆ Outbound  ┆ Pending   ┆ 0.003612  ┆ 0.003587  │
# │            ┆         ┆ on        ┆           ┆   ┆           ┆           ┆           ┆           │
# └────────────┴─────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# The same interaction can occur multiple times: once when the first decision is made, then later when responses are captured (accepted, sent, clicked, etc.). For some of the analyses we need to group the positive outcomes by interaction. This is how that data looks like:

# %%
ih.aggregates.summarize_by_interaction(by=["Channel"]).head().collect()
# Out:
# shape: (5, 6)
# ┌─────────┬───────────────┬───────────────────┬───────────────────┬───────────────────┬────────────┐
# │ Channel ┆ InteractionID ┆ Interaction_Outco ┆ Interaction_Outco ┆ Interaction_Outco ┆ Propensity │
# │ ---     ┆ ---           ┆ me_Engagement     ┆ me_OpenRate       ┆ me_Conversion     ┆ ---        │
# │ str     ┆ str           ┆ ---               ┆ ---               ┆ ---               ┆ f64        │
# │         ┆               ┆ bool              ┆ bool              ┆ bool              ┆            │
# ╞═════════╪═══════════════╪═══════════════════╪═══════════════════╪═══════════════════╪════════════╡
# │ Web     ┆ 1000067214    ┆ false             ┆ null              ┆ false             ┆ 0.00727    │
# │ Web     ┆ 1000006565    ┆ false             ┆ null              ┆ false             ┆ 0.010016   │
# │ Web     ┆ 1000006961    ┆ false             ┆ null              ┆ false             ┆ 0.010418   │
# │ Email   ┆ 1000010959    ┆ null              ┆ false             ┆ false             ┆ 0.019126   │
# │ Web     ┆ 1000011295    ┆ false             ┆ null              ┆ false             ┆ 0.006197   │
# └─────────┴───────────────┴───────────────────┴───────────────────┴───────────────────┴────────────┘

# %% [markdown]
# ## Distribution Analysis
#
# A distribution of the offers (actions/treatments) is often the most obvious type of analysis. You can do an action distribution for specific outcomes (what is offered, what is accepted), view it conditionally (what got offered last month vs this month) - possibly with a delta view, or over time.

# %%
ih.plot.response_count_tree_map()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="ddf80777-43f2-481e-8902-86d0eca54fa1" class="plotly-graph-div" style="height:640px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ddf80777-43f2-481e-8902-86d0eca54fa1")) {                    Plotly.newPlot(                        "ddf80777-43f2-481e-8902-86d0eca54fa1",                        [{"branchvalues":"total","customdata":{"dtype":"f8","bdata":"AAAAAABAdEAAAAAAAAAkQAAAAAAAADJAAAAAAABgbUAAAAAAAADwPwAAAAAAAPA\\u002fAAAAAAAAEEAAAAAAAIBCQAAAAAAAAERAAAAAAACAYkAAAAAAAABCQAAAAAAAwFJAAAAAAAAAGEAAAAAAAADwPwAAAAAAACJAAAAAAAAwf0AAAAAAADB2QAAAAAAAAPA\u002fAAAAAAAAO0AAAAAAAAAqQAAAAAAAAFhAAAAAAAAA8D8AAAAAAAAIQAAAAAAAAPA\u002fAAAAAAAAMkAAAAAAAIBHQAAAAAAAABBAAAAAAACASEAAAAAAAAAqQAAAAAAAwF5AAAAAAADAZkAAAAAAACB2QAAAAAAAgFdAAAAAAAAAGEAAAAAAAAAIQAAAAAAAYGtAAAAAAACAQ0AAAAAAAFiCQAAAAAAAIHZAAAAAAABgYUAAAAAAAAA\...\u002fAAAAAAAAAEAAAAAAAEBdQAAAAAAAoG9AAAAAAAAA8D8AAAAAAAAAQAAAAAAAAPA\u002fAAAAAAAAcEAAAAAAAIBMQAAAAAAAyIBAAAAAAADgaUAAAAAAAAAAQAAAAAAAACZAAAAAAAAAEEAAAAAAAAAYQAAAAAAAAAhAAAAAAAAAFEAAAAAAAAAsQAAAAAAA0HRAAAAAAABggkAAAAAAAAAQQAAAAAAAAABAAAAAAABAYUAAAAAAAADwPwAAAAAAABRAAAAAAABAXEAAAAAAAEB1QAAAAAAAAPA\...\u002fAAAAAAAA8D8AAAAAAOByQAAAAAAAAPA\u002fAAAAAAAAd0AAAAAAAABFQAAAAAAAAEJAAAAAAABAb0AAAAAAAADwPwAAAAAAsHFAAAAAAAAAgEAAAAAAAAAAQAAAAAAAAEBAAAAAAAAACEAAAAAAAGBrQAAAAAAAAPA\\u002fAAAAAAAAV0AAAAAAAABEQAAAAAAAcHBAAAAAAADAUUAAAAAAAPB4QAAAAAAAAABAAAAAAAAAXkAAAAAAAABiQAAAAAAAwHZAAAAAAACwcUAAAAAAAAAIQAAAAAAAAPA\u002fAAAAAADgaEAAAAAAACB0QAAAAAAAAPA\u002fAAAAAAAAEEAAAAAAAADwPwAAAAAAADJAAAAAAAAAMkAAAAAAAABDQAAAAAAAAPA\u002fAAAAAAAAGEAAAAAAAADwPwAAAAAAAFZAAAAAAADAYUAAAAAAAECAQAAAAAAAAPA\u002fAAAAAADAakAAAAAAAAAAQAAAAAAAAAhAAAAAAAAAFEAAAAAAAABPQAAAAAAAAChAAAAAAAAA8D8AAAAAACBhQAAAAAAAwG9AAAAAAAAA8D8AAAAAANB5QAAAAAAAQGlAAAAAAADgZkAAAAAAAAAcQAAAAAAAgHVAAAAAAAAAFEAAAAAAAAAAQAAAAAAAAPA\u002fAAAAAAAAZEAAAAAAAFByQAAAAAAAAPA\u002fAAAAAAAAHEAAAAAAAIBuQAAAAAAAwHFAAAAAAAAAEEAAAAAAAAAAQAAAAAAAgEVAAAAAAACgdEAAAAAAAADwPwAAAAAAAPA\\u002fQAAAAAAAAPA\u002fAAAAAAAAAEAAAAAAAAAyQAAAAAAAAEVAAAAAAAAAW0AAAAAAAACCQAAAAAAAABhAAAAAAABwcUAAAAAAAAAAQAAAAAAAAAhAAAAAAAAgbEAAAAAAAIBhQAAAAAAAQGRAAAAAAACge0AAAAAAAAAyQAAAAAAAwFtAAAAAAAAA8D8AAAAAAAA1QAAAAAAAAGNAAAAAAAAAKEAAAAAAAADwPwAAAAAAAABAAAAAAAAA8D8AAAAAAIB\u002fQAAAAAAAMH1AAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAADgYkAAAAAAAADwPwAAAAAAAAhAAAAAAAAA8D8AAAAAAOBhQAAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAAAyQAAAAAAAABRAAAAAAAAARkAAAAAAAIBXQAAAAAAAUHVAAAAAAAAACEAAAAAAAADwPwAAAAAAAPA\u002fAAAAAACAV0AAAAAAAABdQAAAAAAAAABAAAAAAADgZkAAAAAAAAAsQAAAAAAAAPA\u002fAAAAAAAwcUAAAAAAAPB9QAAAAAAAAPA\u002fAAAAAACAQ0AAAAAAAMBQQAAAAAAAAPA\u002fAAAAAAAAIE ...

# %%
fig = ih.plot.action_distribution(
    query=pl.col.Outcome.is_in(["Clicked", "Accepted"]), 
    title="Distribution of Actions",
    color="Outcome",
)
# fig.update_layout(yaxis=dict(tickmode="linear")) # to show all names
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="f6c788e5-983a-4113-8818-343f3334f2cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f6c788e5-983a-4113-8818-343f3334f2cc")) {                    Plotly.newPlot(                        "f6c788e5-983a-4113-8818-343f3334f2cc",                        [{"hovertemplate":"Outcome=Accepted\u003cbr\u003eCount=%{x}\u003cbr\u003eName=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accepted","marker":{"color":"#001F5F","pattern":{"shape":""}},"name":"Accepted","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"u1","bdata":"AQEBAQEBAgICAgMDAwMDAwQEBAUFBQUGBgYGBwcICAkJCQoLCw0NDhASEhgcHiIjKTBP"},"xaxis":"x","y":["Lending_7","Lending_9","Lending_3","Lending_6","Pension_8","Mortgages_7","Savings_10","Insurance_10","Lending_5","Pension_4","Mortgages_8","Lending_4","Mortgages_9","Insurance_8","Investments_6","Pension_3","Savings_9","Lending_2","Investments_8","Pension_2","Insurance_9","Mortgages_6","Investments_7","Pension_1","Savings_8","Pension_5","Lending_1","Investments_4","Insurance_7","Mortgages_5","Savings_7","Insurance_5","Mortgages_4","Investments_5","Mortgages_3","Insurance_6","Investments_3","Mortgages_2","Savings_5","Savings_6","Mortgages_1","Investments_2","Insurance_4","Investments_1","Savings_4","Savings_3","Insurance_3","Savings_2","Insurance_2","Savings_1","Insurance_1"],"yaxis":"y","type":"bar"},{"hovertemplate":"Outcome=Clicked\u003cbr\u003eCount=%{x}\u003cbr\u003eName=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clicked","marker":{"color":"#10A5AC","pattern":{"shape":""}},"name":"Clicked","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"u1","bdata":"AQEBAQECAgICAgIDAwMEBAQFBQUGBgYGBgcHBwgICQkJCwsNDxITExMUFBwcHx8kJS0vQEFOd5I="},"xaxis":"x","y":["Pension_9","Pension_7","Mortgages_10","Lending_8","Investments_9","Savings_10","Pension_8","Investments_10","Savings_9","Lending_7","Insurance_10","Savings_8","Insurance_9","Lending_4","Lending_6","Pension_4","Mortgages_9","Lending_3","Lending_5","Mortgages_7","Pension_3","Pension_5","Investments_8","Pension_1","Mortgages_8","Investments_7","Investments_4","Lending_2","Insurance_8","Investments_6","Savings_7","Lending_1","Pension_2","Insurance_7","Investments_5","Mortgages_5","Mortgages_6","Insurance_6","Mortgages_4","Mortgages_3","Mortgages_2","Investments_3","Savings_6","Savings_5","Insurance_5","Investments_1","Mortgages_1","Insurance_4","Investments_2","Savings_4","Savings_3","Insurance_3","Savings_2","Insurance_2","Savings_1","Insurance_1"],"yaxis":"y","type":"bar"}],                        {"template":{"layout":{"annotationdefaults":{"font":{"size":12}},"colorway":["#001F5F","#10A5AC","#F76923","#661D34","#86CAC6","#005154","#86CAC6","#5F67B9","#FFC836","#E63690","#AC1361","#63666F","#A7A9B4","#D0D1DB"],"font":{"family":"Open Sans, Arial, sans-serif","size":12},"hovermode":"closest","legend":{"bgcolor":"rgba(255,255,255,0.7)","borderwidth":0},"margin":{"b":50,"l":60,"r":30,"t":60},"title":{"font":{"size":16},"x":0.02,"xanchor":"left"},"xaxis":{"automargin":true,"title":{"standoff":8}},"yaxis":{"automargin":true,"title":{"standoff":8}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Count"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":""},"categoryorder":"total ascending"},"legend":{"title":{"text":"Outcome"},"tracegroupgap":0},"title":{"text":"Distribution of Actions"},"barmode":"stack"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('f6c788e5-983a-4113-8818-343f3334f2cc');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## Response Analysis
#
# A simple view of the responses over time shows how many responses are received per day (or any other period).

# %%
ih.plot.response_count(every="1d")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="27a92496-75be-4b0b-8b19-1483570f5c73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("27a92496-75be-4b0b-8b19-1483570f5c73")) {                    Plotly.newPlot(                        "27a92496-75be-4b0b-8b19-1483570f5c73",                        [{"hovertemplate":"Outcome=Conversion\u003cbr\u003eOutcomeTime=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Conversion","marker":{"color":"#001F5F","pattern":{"shape":""}},"name":"Conversion","orientation":"v","showlegend":true,"textposition":"auto","x":["2026-02-24T00:00:00.000000","2026-01-23T00:00:00.000000","2026-02-20T00:00:00.000000","2026-01-24T00:00:00.000000","2026-04-12T00:00:00.000000","2026-01-31T00:00:00.000000","2026-04-14T00:00:00.000000","2026-04-06T00:00:00.000000","2026-03-17T00:00:00.000000","2026-03-18T00:00:00.000000","2026-01-25T00:00:00.000000","2026-03-04T00:00:00.000000","2026-02-21T00:00:00.000000","2026-04-05T00:00:00.000000","2026-03-16T00:00:00.000000","2026-02-17T00:00:00.000000","2026-02-14T00:00:00.000000","2026-02-10T00:00:00.000000","2026-04-17T00:00:00.000000","2026-02-05T00:00:00.000000","2026-02-02T00:00:00.000000","2026-03-03T00:00:00.000000","2026-03-02T00:00:00.000000","2026-01-27T00:00:00.000000","2026-04-10T00:00:00.000000","2026-03-30T00:00:00.000000","2026-04-13T00:00:00.000000","2026-02-06T00:00:00.000000","2026-02-03T00:00:00.000000","2026-04-03T00:00:00.000000","2026-03-28T00:00:00.000000","2026-03-01T00:00:00.000000","2026-04-02T00:00:00.000000","2026-02-16T00:00:00.000000","2026-04-22T00:00:00.000000","2026-04-18T00:00:00.000000","2026-03-10T00:00:00.000000","2026-03-07T00:00:00.000000","2026-02-15T00:00:00.000000","2026-02-01T00:00:00.000000","2026-04-11T00:00:00.000000","2026-03-26T00:00:00.000000","2026-03-15T00:00:00.000000","2026-03-14T00:00:00.000000","2026-03-08T00:00:00.000000","2026-02-25T00:00:00.000000","2026-03-13T00:00:00.000000","2026-04-08T00:00:00.000000","2026-03-12T00:00:00.000000","2026-03-22T00:00:00.000000","2026-02-27T00:00:00.000000","2026-03-21T00:00:00.000000","2026-03-29T00:00:00.000000","2026-02-11T00:00:00.000000","2026-01-26T00:00:00.000000","2026-03-19T00:00:00.000000","2026-03-05T00:00:00.000000","2026-02-19T00:00:00.000000","2026-02-09T00:00:00.000000","2026-03-27T00:00:00.000000","2026-02-28T00:00:00.000000","2026-02-26T00:00:00.000000","2026-04-20T00:00:00.000000","2026-04-01T00:00:00.000000","2026-02-22T00:00:00.000000","2026-02-08T00:00:00.000000","2026-04-15T00:00:00.000000","2026-03-06T00:00:00.000000","2026-04-21T00:00:00.000000","2026-03-20T00:00:00.000000","2026-03-11T00:00:00.000000","2026-02-04T00:00:00.000000","2026-02-13T00:00:00.000000","2026-04-16T00:00:00.000000","2026-04-04T00:00:00.000000","2026-01-29T00:00:00.000000","2026-04-09T00:00:00.000000","2026-01-28T00:00:00.000000","2026-04-19T00:00:00.000000","2026-02-12T00:00:00.000000","2026-01-30T00:00:00.000000","2026-03-25T00:00:00.000000","2026-02-18T00:00:00.000000","2026-03-24T00:00:00.000000","2026-03-09T00:00:00.000000","2026-02-07T00:00:00.000000","2026-02-23T00:00:00.000000","2026-04-07T00:00:00.000000","2026-03-23T00:00:00.000000","2026-03-31T00:00:00.000000"],"xaxis":"x","y":{"dtype":"u1","bdata":"AQECAwMDBAQEBAQEBAQEBAQEBQUFBQUFBQUFBQUGBgYGBgYGBgYGBgYGBgcHBwcHBwcHCAgICAgICAgJCQkJCQkJCQkKCgoKCgoKCgoKCwsLCwsLCwsMDAwO"},"yaxis":"y","type":"bar"},{"hovertemplate":"Outcome=Accepted\u003cbr\u003eOutcomeTime=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accepted","marker":{"color":"#10A5AC","pattern":{"shape":""}},"name":"Accepted","orientation":"v","showlegend":true,"textposition":"auto","x":["2026-02-14T00: ...

# %% [markdown]
# Which could be viewed per channel as well:

# %%
ih.plot.response_count(
    facet="Channel",
    query=pl.col.Channel != "",
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="7c1e41bd-745e-43a7-95e2-4057ce256e7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7c1e41bd-745e-43a7-95e2-4057ce256e7f")) {                    Plotly.newPlot(                        "7c1e41bd-745e-43a7-95e2-4057ce256e7f",                        [{"hovertemplate":"Outcome=Conversion\u003cbr\u003eChannel=Email\u003cbr\u003eOutcomeTime=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Conversion","marker":{"color":"#001F5F","pattern":{"shape":""}},"name":"Conversion","orientation":"v","showlegend":true,"textposition":"auto","x":["2026-02-11T00:00:00.000000","2026-02-14T00:00:00.000000","2026-01-27T00:00:00.000000","2026-03-07T00:00:00.000000","2026-04-14T00:00:00.000000","2026-03-16T00:00:00.000000","2026-04-17T00:00:00.000000","2026-01-24T00:00:00.000000","2026-03-03T00:00:00.000000","2026-01-31T00:00:00.000000","2026-02-05T00:00:00.000000","2026-03-17T00:00:00.000000","2026-02-10T00:00:00.000000","2026-04-13T00:00:00.000000","2026-04-06T00:00:00.000000","2026-03-10T00:00:00.000000","2026-02-26T00:00:00.000000","2026-03-18T00:00:00.000000","2026-03-02T00:00:00.000000","2026-02-06T00:00:00.000000","2026-04-12T00:00:00.000000","2026-04-05T00:00:00.000000","2026-04-22T00:00:00.000000","2026-02-03T00:00:00.000000","2026-03-01T00:00:00.000000","2026-02-15T00:00:00.000000","2026-04-18T00:00:00.000000","2026-01-25T00:00:00.000000","2026-02-04T00:00:00.000000","2026-02-21T00:00:00.000000","2026-03-04T00:00:00.000000","2026-04-16T00:00:00.000000","2026-02-28T00:00:00.000000","2026-02-27T00:00:00.000000","2026-02-02T00:00:00.000000","2026-02-19T00:00:00.000000","2026-04-02T00:00:00.000000","2026-03-14T00:00:00.000000","2026-02-08T00:00:00.000000","2026-02-17T00:00:00.000000","2026-03-30T00:00:00.000000","2026-03-23T00:00:00.000000","2026-02-09T00:00:00.000000","2026-03-26T00:00:00.000000","2026-02-18T00:00:00.000000","2026-04-19T00:00:00.000000","2026-04-04T00:00:00.000000","2026-03-22T00:00:00.000000","2026-03-15T00:00:00.000000","2026-02-01T00:00:00.000000","2026-03-27T00:00:00.000000","2026-03-12T00:00:00.000000","2026-03-11T00:00:00.000000","2026-03-29T00:00:00.000000","2026-04-01T00:00:00.000000","2026-04-10T00:00:00.000000","2026-02-07T00:00:00.000000","2026-03-08T00:00:00.000000","2026-03-09T00:00:00.000000","2026-04-15T00:00:00.000000","2026-04-07T00:00:00.000000","2026-04-11T00:00:00.000000","2026-03-20T00:00:00.000000","2026-03-13T00:00:00.000000","2026-01-26T00:00:00.000000","2026-03-31T00:00:00.000000","2026-04-08T00:00:00.000000","2026-03-28T00:00:00.000000","2026-01-28T00:00:00.000000","2026-02-12T00:00:00.000000","2026-03-06T00:00:00.000000","2026-04-09T00:00:00.000000","2026-02-13T00:00:00.000000","2026-03-19T00:00:00.000000","2026-02-25T00:00:00.000000","2026-02-22T00:00:00.000000","2026-03-25T00:00:00.000000","2026-03-21T00:00:00.000000","2026-04-21T00:00:00.000000","2026-04-20T00:00:00.000000","2026-02-23T00:00:00.000000","2026-03-05T00:00:00.000000","2026-03-24T00:00:00.000000","2026-01-29T00:00:00.000000"],"xaxis":"x2","y":{"dtype":"u1","bdata":"AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQICAgICAgICAgICAgIDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDBAQEBAQEBAQEBAQEBAQEBAQEBQUFBgYG"},"yaxis":"y2","type":"bar"},{"hovertemplate":"Outcome=Conversion\u003cbr\u003eChannel=Web\u003cbr\u003eOutcomeTime=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Conversion","marker":{"color":"#001F5F","pattern":{"shape":""}},"name":"Conversion","orientation":"v","showlegend":false,"textposition":"auto","x":["2026-02-17T00:00:00.000000","2026-02-24T00:00:00.000000","2026-01-23T00:00:00.000000","2026-02-20T00:00:00.000000","2026-04-10T00:00:00 ...

# %% [markdown]
# ## Success Rates
#
# Success rates (accept rate, open rate, conversion rate) are interesting to track over time. In addition you may want to split by e.g. Channel, or contrast the rates for different experimental setups in an A-B testing set-up.

# %%
ih.plot.success_rate(
    facet="Channel", query=pl.col.Channel.is_not_null() & (pl.col.Channel != "")
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="ee9f8bb1-815b-4066-a803-d29974fc16d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ee9f8bb1-815b-4066-a803-d29974fc16d5")) {                    Plotly.newPlot(                        "ee9f8bb1-815b-4066-a803-d29974fc16d5",                        [{"hovertemplate":"Channel=Email\u003cbr\u003eOutcomeTime=%{x}\u003cbr\u003eSuccessRate_Engagement=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Email","line":{"color":"#001F5F","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Email","orientation":"v","showlegend":true,"x":["2026-01-22T00:00:00.000000","2026-01-23T00:00:00.000000","2026-01-24T00:00:00.000000","2026-01-25T00:00:00.000000","2026-01-26T00:00:00.000000","2026-01-27T00:00:00.000000","2026-01-28T00:00:00.000000","2026-01-29T00:00:00.000000","2026-01-30T00:00:00.000000","2026-01-31T00:00:00.000000","2026-02-01T00:00:00.000000","2026-02-02T00:00:00.000000","2026-02-03T00:00:00.000000","2026-02-04T00:00:00.000000","2026-02-05T00:00:00.000000","2026-02-06T00:00:00.000000","2026-02-07T00:00:00.000000","2026-02-08T00:00:00.000000","2026-02-09T00:00:00.000000","2026-02-10T00:00:00.000000","2026-02-11T00:00:00.000000","2026-02-12T00:00:00.000000","2026-02-13T00:00:00.000000","2026-02-14T00:00:00.000000","2026-02-15T00:00:00.000000","2026-02-16T00:00:00.000000","2026-02-17T00:00:00.000000","2026-02-18T00:00:00.000000","2026-02-19T00:00:00.000000","2026-02-20T00:00:00.000000","2026-02-21T00:00:00.000000","2026-02-22T00:00:00.000000","2026-02-23T00:00:00.000000","2026-02-24T00:00:00.000000","2026-02-25T00:00:00.000000","2026-02-26T00:00:00.000000","2026-02-27T00:00:00.000000","2026-02-28T00:00:00.000000","2026-03-01T00:00:00.000000","2026-03-02T00:00:00.000000","2026-03-03T00:00:00.000000","2026-03-04T00:00:00.000000","2026-03-05T00:00:00.000000","2026-03-06T00:00:00.000000","2026-03-07T00:00:00.000000","2026-03-08T00:00:00.000000","2026-03-09T00:00:00.000000","2026-03-10T00:00:00.000000","2026-03-11T00:00:00.000000","2026-03-12T00:00:00.000000","2026-03-13T00:00:00.000000","2026-03-14T00:00:00.000000","2026-03-15T00:00:00.000000","2026-03-16T00:00:00.000000","2026-03-17T00:00:00.000000","2026-03-18T00:00:00.000000","2026-03-19T00:00:00.000000","2026-03-20T00:00:00.000000","2026-03-21T00:00:00.000000","2026-03-22T00:00:00.000000","2026-03-23T00:00:00.000000","2026-03-24T00:00:00.000000","2026-03-25T00:00:00.000000","2026-03-26T00:00:00.000000","2026-03-27T00:00:00.000000","2026-03-28T00:00:00.000000","2026-03-29T00:00:00.000000","2026-03-30T00:00:00.000000","2026-03-31T00:00:00.000000","2026-04-01T00:00:00.000000","2026-04-02T00:00:00.000000","2026-04-03T00:00:00.000000","2026-04-04T00:00:00.000000","2026-04-05T00:00:00.000000","2026-04-06T00:00:00.000000","2026-04-07T00:00:00.000000","2026-04-08T00:00:00.000000","2026-04-09T00:00:00.000000","2026-04-10T00:00:00.000000","2026-04-11T00:00:00.000000","2026-04-12T00:00:00.000000","2026-04-13T00:00:00.000000","2026-04-14T00:00:00.000000","2026-04-15T00:00:00.000000","2026-04-16T00:00:00.000000","2026-04-17T00:00:00.000000","2026-04-18T00:00:00.000000","2026-04-19T00:00:00.000000","2026-04-20T00:00:00.000000","2026-04-21T00:00:00.000000","2026-04-22T00:00:00.000000"],"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAA ...

# %% [markdown]
# ## Model Performance
#
# Similar to Success Rates: typically viewed over time, likely split by channel, conditioned on variations, e.g. NB vs AGB models.

# %%
ih.plot.model_performance_trend(by="Channel", every="1w")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="8213fec0-855d-488d-b9fe-4716b618f99d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8213fec0-855d-488d-b9fe-4716b618f99d")) {                    Plotly.newPlot(                        "8213fec0-855d-488d-b9fe-4716b618f99d",                        [{"hovertemplate":"Channel=Web\u003cbr\u003eOutcomeTime=%{x}\u003cbr\u003ePerformance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Web","line":{"color":"#001F5F","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Web","orientation":"v","showlegend":true,"x":["2026-01-19T00:00:00.000000","2026-01-26T00:00:00.000000","2026-02-02T00:00:00.000000","2026-02-09T00:00:00.000000","2026-02-16T00:00:00.000000","2026-02-23T00:00:00.000000","2026-03-02T00:00:00.000000","2026-03-09T00:00:00.000000","2026-03-16T00:00:00.000000","2026-03-23T00:00:00.000000","2026-03-30T00:00:00.000000","2026-04-06T00:00:00.000000","2026-04-13T00:00:00.000000","2026-04-20T00:00:00.000000"],"xaxis":"x","y":{"dtype":"f8","bdata":"NL+u5pEXUUCRpsMi\u002fLxQQLfgnpjrFlFAKPVT5NYkUUCqfEn6fQhRQFO5EzClslJAHM67l0EBUUAh0sPrxm1RQCTnvasOS09AoEVFtWX1UEDbEfokzidQQEIVR2GbRlBAbGP6ifxHUEACK0be\u002fi5SQA=="},"yaxis":"y","type":"scatter"}],                        {"template":{"layout":{"annotationdefaults":{"font":{"size":12}},"colorway":["#001F5F","#10A5AC","#F76923","#661D34","#86CAC6","#005154","#86CAC6","#5F67B9","#FFC836","#E63690","#AC1361","#63666F","#A7A9B4","#D0D1DB"],"font":{"family":"Open Sans, Arial, sans-serif","size":12},"hovermode":"closest","legend":{"bgcolor":"rgba(255,255,255,0.7)","borderwidth":0},"margin":{"b":50,"l":60,"r":30,"t":60},"title":{"font":{"size":16},"x":0.02,"xanchor":"left"},"xaxis":{"automargin":true,"title":{"standoff":8}},"yaxis":{"automargin":true,"title":{"standoff":8}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"Performance"},"range":[50,null]},"legend":{"title":{"text":"Channel"},"tracegroupgap":0},"title":{"text":"Model Performance over Time"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('8213fec0-855d-488d-b9fe-4716b618f99d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## AGB vs NB analysis
#
# There are different types of ADM models you can use in CDH. This analysis shows the model performance of the (classic) Naive Bayes models vs the new Gradient Boosting models. We split by channel as this often matters.

# %%
fig = ih.plot.model_performance_trend(
    by="ModelTechnique",
    facet="Channel",
    every="1w",
    title="Model Performance of Naive Bayes vs Gradient Boosting Models",
)
fig.update_layout(legend_title_text="Technique")
fig
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="c23b7d15-e671-40c3-9df8-93481fcb17c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c23b7d15-e671-40c3-9df8-93481fcb17c0")) {                    Plotly.newPlot(                        "c23b7d15-e671-40c3-9df8-93481fcb17c0",                        [{"hovertemplate":"ModelTechnique=GradientBoost\u003cbr\u003eChannel=Web\u003cbr\u003eOutcomeTime=%{x}\u003cbr\u003ePerformance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GradientBoost","line":{"color":"#001F5F","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"GradientBoost","orientation":"v","showlegend":true,"x":["2026-01-19T00:00:00.000000","2026-01-26T00:00:00.000000","2026-02-02T00:00:00.000000","2026-02-09T00:00:00.000000","2026-02-16T00:00:00.000000","2026-02-23T00:00:00.000000","2026-03-02T00:00:00.000000","2026-03-09T00:00:00.000000","2026-03-16T00:00:00.000000","2026-03-23T00:00:00.000000","2026-03-30T00:00:00.000000","2026-04-06T00:00:00.000000","2026-04-13T00:00:00.000000","2026-04-20T00:00:00.000000"],"xaxis":"x","y":{"dtype":"f8","bdata":"hgERWNpzUUAfRXIZwmFRQITcgEVKzFJA+eXPw9DEUEBFncnfarBRQMDCohBxd1NA4KeNRf89UUCdRtPSn6VSQDL0sq7EfU5A1HT2YYNZUEDo7\u002fFJ4rZRQLfgnpjrVlBAhdOjQ0LuUEB1J\u002fMh3TlTQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"ModelTechnique=NaiveBayes\u003cbr\u003eChannel=Web\u003cbr\u003eOutcomeTime=%{x}\u003cbr\u003ePerformance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NaiveBayes","line":{"color":"#10A5AC","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"NaiveBayes","orientation":"v","showlegend":true,"x":["2026-01-19T00:00:00.000000","2026-01-26T00:00:00.000000","2026-02-02T00:00:00.000000","2026-02-09T00:00:00.000000","2026-02-16T00:00:00.000000","2026-02-23T00:00:00.000000","2026-03-02T00:00:00.000000","2026-03-09T00:00:00.000000","2026-03-16T00:00:00.000000","2026-03-23T00:00:00.000000","2026-03-30T00:00:00.000000","2026-04-06T00:00:00.000000","2026-04-13T00:00:00.000000","2026-04-20T00:00:00.000000"],"xaxis":"x","y":{"dtype":"f8","bdata":"lXBm24fDUEDHUT\u002fMXV1QQIR+Mpq4aE9AncEKncGKUUBU9ilMSIdQQCRWOfbE91FARs2\u002f2qTQUEApp+62vFdQQJjUFsvjzk9AZJPiX7GfUUCRJrlhcLxOQDnj1zI2Q1BALr+G+UmBT0Bqj6uAYDhRQA=="},"yaxis":"y","type":"scatter"}],                        {"template":{"layout":{"annotationdefaults":{"font":{"size":12}},"colorway":["#001F5F","#10A5AC","#F76923","#661D34","#86CAC6","#005154","#86CAC6","#5F67B9","#FFC836","#E63690","#AC1361","#63666F","#A7A9B4","#D0D1DB"],"font":{"family":"Open Sans, Arial, sans-serif","size":12},"hovermode":"closest","legend":{"bgcolor":"rgba(255,255,255,0.7)","borderwidth":0},"margin":{"b":50,"l":60,"r":30,"t":60},"title":{"font":{"size":16},"x":0.02,"xanchor":"left"},"xaxis":{"automargin":true,"title":{"standoff":8}},"yaxis":{"automargin":true,"title":{"standoff":8}}}},"xaxis":{"anchor":"y","domain":[0.0,0.98],"title":{}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"Performance"},"range":[50,null]},"annotations":[{"font":{},"showarrow":false,"text":"Web","textangle":90,"x":0.98,"xanchor":"left","xref":"paper","y":0.5,"yanchor":"middle","yref":"paper"}],"legend":{"title":{"text":"Technique"},"tracegroupgap":0},"title":{"text":"Model Performance of Naive Bayes vs Gradient Boosting Models"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('c23b7d15-e671-40c3-9df8-93481fcb17c0');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## Propensity Distribution
#
# IH also contains information about the factors that determine the prioritization of the offers: lever values, propensities etc.
#
# Here we show the distribution of the propensities of the offers made. It's also a first example of a custom analysis not currently supported directly by the PDSTools library. You can see how we access the underlying IH data (**ih.data**), then aggregate and display it.

# %%
import plotly.figure_factory as ff

channels = [
    c
    for c in ih.data.select(pl.col.Channel.unique().sort())
    .collect()["Channel"]
    .to_list()
    if c is not None and c != ""
]

plot_data = [
    ih.data.filter(pl.col.Channel == c)
    .select(["Propensity"])
    .collect()["Propensity"]
    .sample(fraction=0.1)
    .to_list()
    for c in channels
]
fig = ff.create_distplot(plot_data, group_labels=channels, show_hist=False)
fig.update_layout(
    title="Propensity Distribution",
    yaxis=dict(showticklabels=False),
    xaxis=dict(title="Propensity", tickformat=".0%"),
    legend_title_text="Channel",
    template="pega",
)
fig
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="442e6a32-71dc-438e-b2cf-d636e82c6029" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("442e6a32-71dc-438e-b2cf-d636e82c6029")) {                    Plotly.newPlot(                        "442e6a32-71dc-438e-b2cf-d636e82c6029",                        [{"legendgroup":"Email","marker":{"color":"rgb(31, 119, 180)"},"mode":"lines","name":"Email","showlegend":true,"x":[0.001115632456750191,0.0011811689280299491,0.0012467053993097071,0.0013122418705894653,0.0013777783418692235,0.0014433148131489818,0.00150885128442874,0.001574387755708498,0.0016399242269882562,0.0017054606982680144,0.0017709971695477724,0.0018365336408275308,0.0019020701121072888,0.0019676065833870472,0.002033143054666805,0.002098679525946563,0.002164215997226321,0.0022297524685060796,0.002295288939785838,0.002360825411065596,0.002426361882345354,0.002491898353625112,0.0025574348249048705,0.0026229712961846285,0.002688507767464387,0.002754044238744145,0.002819580710023903,0.0028851171813036613,0.0029506536525834197,0.0030161901238631777,0.0030817265951429357,0.0031472630664226937,0.0032127995377024517,0.0032783360089822106,0.0033438724802619686,0.0034094089515417265,0.0034749454228214845,0.0035404818941012425,0.0036060183653810005,0.0036715548366607594,0.0037370913079405174,0.0038026277792202754,0.0038681642505000334,0.003933700721779791,0.00399923719305955,0.004064773664339308,0.004130310135619066,0.004195846606898824,0.004261383078178583,0.004326919549458341,0.004392456020738099,0.004457992492017857,0.004523528963297615,0.004589065434577374,0.004654601905857132,0.00472013837713689,0.004785674848416648,0.004851211319696406,0.004916747790976164,0.004982284262255923,0.005047820733535681,0.005113357204815439,0.005178893676095197,0.005244430147374955,0.005309966618654713,0.005375503089934471,0.0054410395612142295,0.0055065760324939875,0.0055721125037737455,0.0056376489750535035,0.0057031854463332615,0.00576872191761302,0.005834258388892778,0.005899794860172536,0.005965331331452294,0.006030867802732052,0.00609640427401181,0.006161940745291569,0.006227477216571327,0.006293013687851085,0.006358550159130843,0.006424086630410601,0.006489623101690359,0.006555159572970118,0.006620696044249876,0.006686232515529634,0.006751768986809392,0.00681730545808915,0.006882841929368909,0.006948378400648667,0.007013914871928425,0.007079451343208183,0.007144987814487941,0.007210524285767699,0.007276060757047458,0.007341597228327216,0.0074071336996069746,0.0074726701708867325,0.0075382066421664905,0.0076037431134462485,0.007669279584726007,0.007734816056005765,0.007800352527285523,0.007865888998565282,0.00793142546984504,0.007996961941124798,0.008062498412404556,0.008128034883684314,0.008193571354964072,0.00825910782624383,0.008324644297523588,0.008390180768803348,0.008455717240083106,0.008521253711362864,0.008586790182642622,0.00865232665392238,0.008717863125202138,0.008783399596481896,0.008848936067761654,0.008914472539041412,0.008980009010321172,0.00904554548160093,0.009111081952880688,0.009176618424160446,0.009242154895440204,0.009307691366719962,0.00937322783799972,0.009438764309279478,0.009504300780559236,0.009569837251838994,0.009635373723118752,0.009700910194398511,0.00976644666567827,0.009831983136958027,0.009897519608237785,0.009963056079517543,0.010028592550797301,0.01009412902207706,0.010159665493356817,0.010225201964636575,0.010290738435916333,0.010356274907196091,0.010421811378475851,0.010487347849755609,0.010552884321035367,0.010618420792315125,0.010683957263594883,0.010749493734874641,0.010815030206154399,0.010880566677434157,0.010946103148713915,0.011011639619993673,0.01107717609127343,0.011142712562553189,0.011208249033832949,0 ...

# %% [markdown]
# ## Propensity Calibrarion

# %% [markdown]
# We can verify the accurateness of the propensities generated by Pega vs the actual click-through rates by looking at the click through rates in interaction history data. Although there currently is no direct IH plot to do this, the underlying aggregation functions are generic enough to support this.
#
# The plot shows how propensities calibrate against the click through rates in IH.

# %%
import plotly.express as px
px.bar(
    # We simply use qcut to get the equal volume bins. The labels are very long/not very readable. To solve
    # for that we could do a qcut on the raw data first, programatically set the labels etc.
    ih.aggregates.summary_success_rates(
        by=[pl.col("Propensity").qcut(10).alias("PropensityBin"), "Channel", "Direction"]
    )
    .collect()
    .unpivot(
        on=["SuccessRate_Engagement"],
        index=["PropensityBin", "Channel", "Direction"],
        variable_name="KPI",
        value_name="CTR",
    ).with_columns(
        Channel = pl.concat_str("Channel","Direction",separator="/")
    ),
    x="PropensityBin",
    y="CTR",
    facet_row="Channel",
    template="pega",
    title="Propensity Calibration"
).update_xaxes(title="").update_yaxes(tickformat=".2%")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="9d55aaad-00ac-455f-ba8c-7dc8818ac11c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9d55aaad-00ac-455f-ba8c-7dc8818ac11c")) {                    Plotly.newPlot(                        "9d55aaad-00ac-455f-ba8c-7dc8818ac11c",                        [{"hovertemplate":"Channel=Email\u002fOutbound\u003cbr\u003ePropensityBin=%{x}\u003cbr\u003eCTR=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#001F5F","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["(-inf, 0.003976257879288359]","(0.003976257879288359, 0.005520154990198822]","(0.005520154990198822, 0.006968746669859204]","(0.006968746669859204, 0.008706211968816416]","(0.008706211968816416, 0.010867637645519186]","(0.010867637645519186, 0.013719594256681393]","(0.013719594256681393, 0.01754280826549416]","(0.01754280826549416, 0.02312808733217017]","(0.02312808733217017, 0.03222912850470053]","(0.03222912850470053, inf]"],"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8="},"yaxis":"y2","type":"bar"},{"hovertemplate":"Channel=Web\u002fInbound\u003cbr\u003ePropensityBin=%{x}\u003cbr\u003eCTR=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#001F5F","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["(-inf, 0.003976257879288359]","(0.003976257879288359, 0.005520154990198822]","(0.005520154990198822, 0.006968746669859204]","(0.006968746669859204, 0.008706211968816416]","(0.008706211968816416, 0.010867637645519186]","(0.010867637645519186, 0.013719594256681393]","(0.013719594256681393, 0.01754280826549416]","(0.01754280826549416, 0.02312808733217017]","(0.02312808733217017, 0.03222912850470053]","(0.03222912850470053, inf]"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAAA3Jg0gbkx6PwOz9mUwX4I\u002fHb52jBZygz+br9JadPKIP6WS4ZqFSI0\u002f9ELaonJnkT+0Q+DGMiiVP2fl+DXTrpo\u002fB0tIwyQCqD8="},"yaxis":"y","type":"bar"}],                        {"template":{"layout":{"annotationdefaults":{"font":{"size":12}},"colorway":["#001F5F","#10A5AC","#F76923","#661D34","#86CAC6","#005154","#86CAC6","#5F67B9","#FFC836","#E63690","#AC1361","#63666F","#A7A9B4","#D0D1DB"],"font":{"family":"Open Sans, Arial, sans-serif","size":12},"hovermode":"closest","legend":{"bgcolor":"rgba(255,255,255,0.7)","borderwidth":0},"margin":{"b":50,"l":60,"r":30,"t":60},"title":{"font":{"size":16},"x":0.02,"xanchor":"left"},"xaxis":{"automargin":true,"title":{"standoff":8}},"yaxis":{"automargin":true,"title":{"standoff":8}}}},"xaxis":{"anchor":"y","domain":[0.0,0.98],"title":{"text":""}},"yaxis":{"anchor":"x","domain":[0.0,0.485],"title":{"text":"CTR"},"tickformat":".2%"},"xaxis2":{"anchor":"y2","domain":[0.0,0.98],"matches":"x","showticklabels":false,"title":{"text":""}},"yaxis2":{"anchor":"x2","domain":[0.515,1.0],"matches":"y","title":{"text":"CTR"},"tickformat":".2%"},"annotations":[{"font":{},"showarrow":false,"text":"Channel=Web\u002fInbound","textangle":90,"x":0.98,"xanchor":"left","xref":"paper","y":0.2425,"yanchor":"middle","yref":"paper"},{"font":{},"showarrow":false,"text":"Channel=Email\u002fOutbound","textangle":90,"x":0.98,"xanchor":"left","xref":"paper","y":0.7575000000000001,"yanchor":"middle","yref":"paper"}],"legend":{"tracegroupgap":0},"title":{"text":"Propensity Calibration"},"barmode":"relative"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('9d55aaad-00ac-455f-ba8c-7dc8818ac11c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## Response Time Analysis
#
# Time is one of the dimensions in IH. Here we take a look at how subsequent responses relate to the original decision. It shows, for example, how much time there typically is between the moment of decision and the click.
#
# This type of analysis is usually part of attribution analysis when considering conversion modeling.

# %%
import plotly.express as px

outcomes = [
    objective
    for objective in ih.data.select(pl.col.Outcome.unique().sort())
    .collect()["Outcome"]
    .to_list()
    if objective is not None and objective != ""
]
plot_data = (
    ih.data.filter(pl.col.OutcomeTime.is_not_null())
    .group_by("InteractionID")
    .agg(
        [pl.col.OutcomeTime.min().alias("Decision_Time")]
        + [
            pl.col.OutcomeTime.filter(pl.col.Outcome == o).max().alias(o)
            for o in outcomes
        ],
    )
    .collect()
    .unpivot(
        index=["InteractionID", "Decision_Time"],
        variable_name="Outcome",
        value_name="Time",
    )
    .with_columns(Duration=(pl.col.Time - pl.col.Decision_Time).dt.total_seconds())
    .filter(pl.col.Duration > 0)
)

ordered_outcomes = (
    plot_data.group_by("Outcome")
    .agg(Duration=pl.col("Duration").median())
    .sort("Duration")["Outcome"]
    .to_list()
)

fig = px.box(
    plot_data,
    x="Duration",
    y="Outcome",
    color="Outcome",
    template="pega",
    category_orders={"Outcome": ordered_outcomes},
    points=False,
    title="Duration of Responses",
    log_x=True,
)
fig.update_layout(
    xaxis_title="Duration (seconds) with logarithmic scale", yaxis_title=""
)
fig
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="285c148c-25b6-4bfd-9be4-b67ec5ea811e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("285c148c-25b6-4bfd-9be4-b67ec5ea811e")) {                    Plotly.newPlot(                        "285c148c-25b6-4bfd-9be4-b67ec5ea811e",                        [{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Outcome=%{y}\u003cbr\u003eDuration=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clicked","marker":{"color":"#001F5F"},"name":"Clicked","notched":false,"offsetgroup":"Clicked","orientation":"h","showlegend":true,"x":{"dtype":"i2","bdata":"...\u002fAI8APwAlAFYARADMAK4AJACKADIAPgA1AAkAZQAJAN4AqABqANEA7AAYAI4AXQB\\...\..."},"x0":" ","xaxis":"x","y":["Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked","Clicked", ...

# %% [markdown]
# ## Pattern Analysis
#
# This method uncovers patterns in customer behavior by analyzing the sequences of actions that lead to outcomes like conversions.
# By calculating Pointwise Mutual Information (PMI), we highlight strong associations between actions in customer journeys.

# %%
customer_sequences, customer_outcomes, count_actions, count_sequences = ih.get_sequences(
    positive_outcome_label="Conversion", 
    outcome_column="Outcome", 
    level ="Name", 
    customerid_column="InteractionID"
)

sequences = ih.calculate_pmi(count_actions, count_sequences)

sequences_df = ih.pmi_overview(sequences, count_sequences, customer_sequences, customer_outcomes)

sequences_df.head()
# Out:
# shape: (5, 6)
# ┌─────────────────────────────────┬────────┬─────────┬───────────┬─────────────┬────────┐
# │ Sequence                        ┆ Length ┆ Avg PMI ┆ Frequency ┆ Unique freq ┆ Score  │
# │ ---                             ┆ ---    ┆ ---     ┆ ---       ┆ ---         ┆ ---    │
# │ list[str]                       ┆ i64    ┆ f64     ┆ i64       ┆ i64         ┆ f64    │
# ╞═════════════════════════════════╪════════╪═════════╪═══════════╪═════════════╪════════╡
# │ ["Savings_3", "Savings_3"]      ┆ 2      ┆ 5.199   ┆ 29        ┆ 29          ┆ 17.505 │
# │ ["Savings_3", "Savings_3", "Sa… ┆ 3      ┆ 5.199   ┆ 29        ┆ 29          ┆ 17.505 │
# │ ["Savings_4", "Savings_4"]      ┆ 2      ┆ 5.249   ┆ 28        ┆ 28          ┆ 17.492 │
# │ ["Savings_4", "Savings_4", "Sa… ┆ 3      ┆ 5.249   ┆ 28        ┆ 28          ┆ 17.492 │
# │ ["Insurance_2", "Insurance_2"]  ┆ 2      ┆ 4.664   ┆ 42        ┆ 42          ┆ 17.434 │
# └─────────────────────────────────┴────────┴─────────┴───────────┴─────────────┴────────┘
